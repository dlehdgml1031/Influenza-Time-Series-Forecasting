# %%
# 1. 2021/07/06 까지

import os
import pandas as pd
import xml.etree.ElementTree as ET
from datetime import datetime

def parse_xml_to_df(xml_file):
    try:
        with open(xml_file, 'r', encoding='utf-8') as file:
            xml_content = file.read()
        
        # Parse the XML content
        root = ET.fromstring(xml_content)

        # Prepare lists to store the data
        titles = []
        pub_dates = []

        # Iterate through each item in the XML
        for item in root.findall('item'):
            # Check if the language is 'en'
            language = item.find('ns0language')
            if language is not None and language.text == 'en':
                # Extract title, description, and pubDate
                title = item.find('title').text if item.find('title') is not None else ''
                pub_date = item.find('pubDate').text if item.find('pubDate') is not None else ''
                
                # Convert pub_date to the desired format (YYYY-MM-DD)
                if pub_date:
                    pub_date = datetime.strptime(pub_date, '%a, %d %b %Y %H:%M:%S %z').strftime('%Y-%m-%d')
                
                # Append to lists
                titles.append(title)
                pub_dates.append(pub_date)

        # Create a DataFrame
        df = pd.DataFrame({
            'Title': titles,
            'Date': pub_dates
        })

        return df

    except ET.ParseError as e:
        print(f"Error parsing {xml_file}: {e}")
        return pd.DataFrame()

def process_all_xml_files(root_folder):
    all_dfs = []
    
    # Iterate through each folder in the root directory
    for folder_name in os.listdir(root_folder):
        folder_path = os.path.join(root_folder, folder_name)
        
        if os.path.isdir(folder_path):
            # Iterate through each XML file in the folder
            for file_name in os.listdir(folder_path):
                if file_name.endswith('.xml'):
                    file_path = os.path.join(folder_path, file_name)
                    df = parse_xml_to_df(file_path)
                    if not df.empty:
                        all_dfs.append(df)

    # Concatenate all dataframes
    final_df = pd.concat(all_dfs, ignore_index=True)
    
    return final_df

def save_df_to_csv(df, output_file):
    df.to_csv(output_file, index=False, encoding='utf-8')

# Example usage
root_folder_path = 'data/news'  # Change this to the path of the root folder containing the dated folders
output_csv_path = 'filtered_news_title_1.csv'

final_df = process_all_xml_files(root_folder_path)
save_df_to_csv(final_df, output_csv_path)
# Out:
# C:\Users\gmleh\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\gmleh\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Error parsing data/news\20180927\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20180928\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20180929\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20180930\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181001\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181002\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181003\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181004\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181005\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181007\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181008\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181009\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181010\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181011\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181012\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181013\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181014\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181015\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181016\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181017\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181018\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181019\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181022\Yersinia Pestis (Plague).xml: no element found: line 1, column 0
# Error parsing data/news\20181023\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181024\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181025\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181026\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181027\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181028\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181029\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181030\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181031\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181101\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181102\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181103\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181104\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181105\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181106\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181107\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181108\Healthcare Associated Infections.xml: unclosed token: line 5, column 3917
# Error parsing data/news\20181108\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181109\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181110\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181111\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181112\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181113\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181114\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181115\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181116\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181117\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181118\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181119\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181120\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181121\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181122\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181123\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181124\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181125\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181126\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181127\Poliomyelitis.xml: no element found: line 14, column 8993
# Error parsing data/news\20181127\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181128\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181129\Malaria.xml: unclosed token: line 12, column 4531
# Error parsing data/news\20181129\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181130\Poliomyelitis.xml: no element found: line 6, column 41492
# Error parsing data/news\20181130\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181201\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181202\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181203\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181204\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181205\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181206\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181207\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181208\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181209\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181210\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181211\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181212\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181213\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181214\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181215\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181216\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181217\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181218\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181219\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181220\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181221\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181222\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181223\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181224\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181225\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181226\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181227\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181228\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181229\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181230\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20181231\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20190101\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20190102\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20190103\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20190104\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20190105\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20190106\Yersinia Pestis (Plague).xml: mismatched tag: line 1, column 956
# Error parsing data/news\20
xml: no element found: line 1, column 0
# Error parsing data/news\20220414\Nosocomial.xml: no element found: line 1, column 0
# Error parsing data/news\20220414\Pneumonia.xml: no element found: line 1, column 0
# Error parsing data/news\20220414\Poliomyelitis.xml: no element found: line 1, column 0
# Error parsing data/news\20220414\Swine Flu.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Anisakis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Ascaris.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Avian flu.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Botulism.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Chagas disease.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Chikungunya.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Coccidioidomycosis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Communicable disease.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Congo-Crimean HF.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Coronavirus Infection.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Coxsackie Infection.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\CreutzfeldtJakobDisease.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Diphtheria.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Ebola Hemorrhagic Fever.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Enteritis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Enterobiasis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Escherichia coli Infection.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Fasciola.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Filovirus.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Food poisoning.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Food-borne.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Giardiasis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Gonococcal.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Haemophilus influenzae Infection.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Healthcare Associated Infections.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Hepatitis A.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Hepatitis B.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Hepatitis C.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Lassa Fever.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Legionellosis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Leishmaniasis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Leprosy.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Lyme disease.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Measles.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Mumps.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Norovirus.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Nosocomial.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Onchocerciasis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Poliomyelitis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Q Fever.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Rabies.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Respiratory Syncytial Virus Infection.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Salmonellosis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\SARS.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Saxitoxin Poisoning.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Sleeping Sickness.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\STD.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Strongyloidiasis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Swine Flu.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Tetanus.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Toxoplasma.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Trichuris.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Tuberculosis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Tularemia.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Typhoid Fever.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Viral hepatitis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Visceral Leishmaniasis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\West Nile Disease.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Yaws.xml: no element found: line 1, column 0

# %%
import os
import pandas as pd
import xml.etree.ElementTree as ET
from datetime import datetime, timedelta

def parse_xml_to_df(xml_file):
    try:
        with open(xml_file, 'r', encoding='utf-8') as file:
            xml_content = file.read()
        
        # Parse the XML content
        root = ET.fromstring(xml_content)

        # Extract namespaces
        namespaces = {'ns0': root.tag.split('}')[0].strip('{')}

        # Prepare lists to store the data
        titles = []
        pub_dates = []

        # Iterate through each item in the XML
        for item in root.findall('item'):
            # Check if the language is 'en'
            language = item.find('ns1language', namespaces)
            if language is not None and language.text == 'en':
                # Extract title and pubDate
                title = item.find('title').text if item.find('title') is not None else ''
                pub_date = item.find('pubDate').text if item.find('pubDate') is not None else ''
                
                # Convert pub_date to the desired format (YYYY-MM-DD) or set it to an empty string
                if pub_date:
                    pub_date = datetime.strptime(pub_date, '%a, %d %b %Y %H:%M:%S %z').strftime('%Y-%m-%d')
                else:
                    pub_date = ''

                # Append to lists
                titles.append(title)
                pub_dates.append(pub_date)

        # Create a DataFrame if lists are not empty
        if titles:
            df = pd.DataFrame({
                'Title': titles,
                'Date': pub_dates
            })
            return df
        else:
            return pd.DataFrame()

    except ET.ParseError as e:
        print(f"Error parsing {xml_file}: {e}")
        return pd.DataFrame()

def process_all_xml_files(root_folder, start_date, end_date):
    all_dfs = []
    current_date = start_date
    
    while current_date <= end_date:
        folder_name = current_date.strftime('%Y%m%d')
        folder_path = os.path.join(root_folder, folder_name)
        
        if os.path.isdir(folder_path):
            # Iterate through each XML file in the folder
            for file_name in os.listdir(folder_path):
                if file_name.endswith('.xml'):
                    file_path = os.path.join(folder_path, file_name)
                    df = parse_xml_to_df(file_path)
                    if not df.empty:
                        all_dfs.append(df)
        else:
            print(f"Folder {folder_name} does not exist. Skipping.")
        
        # Move to the next day
        current_date += timedelta(days=1)

    # Concatenate all dataframes if any
    if all_dfs:
        final_df = pd.concat(all_dfs, ignore_index=True)
    else:
        final_df = pd.DataFrame(columns=['Title', 'Date'])
    
    return final_df

def save_df_to_csv(df, output_file):
    df.to_csv(output_file, index=False, encoding='utf-8')

# Example usage
root_folder_path = 'data/news'  # Change this to the path of the root folder containing the dated folders
start_date = datetime.strptime('20210701', '%Y%m%d')
end_date = datetime.strptime('20230922', '%Y%m%d')
output_csv_path = 'filtered_news_title_2.csv'

final_df = process_all_xml_files(root_folder_path, start_date, end_date)
save_df_to_csv(final_df, output_csv_path)
# Out:
# Error parsing data/news\20210701\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210702\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210703\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210704\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210705\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210706\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210707\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210708\Hymenolepsis.xml: not well-formed (invalid token): line 1, column 1007
# Error parsing data/news\20210708\SchmallenbergVirus.xml: not well-formed (invalid token): line 1, column 6056
# Error parsing data/news\20210708\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210709\Hymenolepsis.xml: not well-formed (invalid token): line 1, column 1007
# Error parsing data/news\20210709\SchmallenbergVirus.xml: not well-formed (invalid token): line 1, column 6056
# Error parsing data/news\20210709\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210710\Hymenolepsis.xml: not well-formed (invalid token): line 1, column 1007
# Error parsing data/news\20210710\SchmallenbergVirus.xml: not well-formed (invalid token): line 1, column 6056
# Error parsing data/news\20210710\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210711\SchmallenbergVirus.xml: not well-formed (invalid token): line 1, column 6056
# Error parsing data/news\20210711\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210712\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210713\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210714\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210715\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210716\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210717\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210718\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210719\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210720\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210721\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210722\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210723\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210724\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210725\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210726\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210727\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210728\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210729\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210730\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210731\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210801\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210802\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210803\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210804\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210805\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210806\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210807\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210808\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20210809\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Folder 20210814 does not exist. Skipping.
# Folder 20210815 does not exist. Skipping.
# Folder 20210822 does not exist. Skipping.
# Folder 20210823 does not exist. Skipping.
# Error parsing data/news\20210909\Ebola Hemorrhagic Fever.xml: no element found: line 6, column 212080
# Folder 20211001 does not exist. Skipping.
# Folder 20211002 does not exist. Skipping.
# Folder 20211003 does not exist. Skipping.
# Folder 20211004 does not exist. Skipping.
# Folder 20211005 does not exist. Skipping.
# Folder 20211006 does not exist. Skipping.
# Folder 20211007 does not exist. Skipping.
# Folder 20211008 does not exist. Skipping.
# Folder 20211009 does not exist. Skipping.
# Folder 20211010 does not exist. Skipping.
# Folder 20211011 does not exist. Skipping.
# Folder 20211012 does not exist. Skipping.
# Folder 20211013 does not exist. Skipping.
# Folder 20211014 does not exist. Skipping.
# Folder 20211015 does not exist. Skipping.
# Folder 20211016 does not exist. Skipping.
# Folder 20211017 does not exist. Skipping.
# Folder 20211018 does not exist. Skipping.
# Folder 20211019 does not exist. Skipping.
# Folder 20211020 does not exist. Skipping.
# Folder 20211021 does not exist. Skipping.
# Folder 20211022 does not exist. Skipping.
# Folder 20211023 does not exist. Skipping.
# Folder 20211024 does not exist. Skipping.
# Folder 20211025 does not exist. Skipping.
# Folder 20211026 does not exist. Skipping.
# Folder 20211027 does not exist. Skipping.
# Folder 20211028 does not exist. Skipping.
# Folder 20211029 does not exist. Skipping.
# Folder 20211030 does not exist. Skipping.
# Folder 20211031 does not exist. Skipping.
# Folder 20211101 does not exist. Skipping.
# Folder 20211212 does not exist. Skipping.
# Folder 20211213 does not exist. Skipping.
# Folder 20211214 does not exist. Skipping.
# Error parsing data/news\20211215\Anisakis.xml: syntax error: line 1, column 0
# Error parsing data/news\20211215\Anthrax.xml: syntax error: line 1, column 0
# Error parsing data/news\20211215\Ascaris.xml: syntax error: line 1, column 0
# Error parsing data/news\20211215\Avian flu.xml: syntax error: line 1, column 0
# Error parsing data/news\20211215\Babesiosis.xml: syntax error: line 1, column 0
# Error parsing data/news\20211215\Botulism.xml: syntax error: line 1, column 0
# Error parsing data/news\20211215\Brucellosis.xml: syntax error: line 1, column 0
# Error parsing data/news\20211215\
is.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Roseolo virus.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Rotavirus.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Rubella.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Salmonellosis.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\SARS.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Saxitoxin Poisoning.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Scabies.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Schistosomiasis.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\SchmallenbergVirus.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Shigellosis.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Sleeping Sickness.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Smallpox.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\STD.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Strongyloidiasis.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Swine Flu.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Syphilis.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Tetanus.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Toxoplasma.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Trachoma.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Trichinella.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Trichomoniasis.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Trichuris.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\TSE.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Tuberculosis.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Tularemia.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Typhoid Fever.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Viral hepatitis.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Visceral Leishmaniasis.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\West Nile Disease.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Yaws.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Yellow Fever.xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Yersinia Pestis (Plague).xml: syntax error: line 1, column 0
# Error parsing data/news\20211216\Zika Virus.xml: syntax error: line 1, column 0
# Error parsing data/news\20220414\Equine encephalitis.xml: no element found: line 1, column 0
# Error parsing data/news\20220414\Hanta Fever.xml: no element found: line 1, column 0
# Error parsing data/news\20220414\Leishmaniasis.xml: no element found: line 1, column 0
# Error parsing data/news\20220414\Leptospirosis.xml: no element found: line 1, column 0
# Error parsing data/news\20220414\Malaria.xml: no element found: line 1, column 0
# Error parsing data/news\20220414\Measles.xml: no element found: line 1, column 0
# Error parsing data/news\20220414\Meningitis.xml: no element found: line 1, column 0
# Error parsing data/news\20220414\Mumps.xml: no element found: line 1, column 0
# Error parsing data/news\20220414\Nosocomial.xml: no element found: line 1, column 0
# Error parsing data/news\20220414\Pneumonia.xml: no element found: line 1, column 0
# Error parsing data/news\20220414\Poliomyelitis.xml: no element found: line 1, column 0
# Error parsing data/news\20220414\Swine Flu.xml: no element found: line 1, column 0
# Folder 20220423 does not exist. Skipping.
# Folder 20220730 does not exist. Skipping.
# Folder 20220731 does not exist. Skipping.
# Folder 20220801 does not exist. Skipping.
# Folder 20220803 does not exist. Skipping.
# Folder 20220903 does not exist. Skipping.
# Folder 20220904 does not exist. Skipping.
# Folder 20220905 does not exist. Skipping.
# Folder 20221025 does not exist. Skipping.
# Folder 20221202 does not exist. Skipping.
# Folder 20221206 does not exist. Skipping.
# Folder 20221207 does not exist. Skipping.
# Folder 20221211 does not exist. Skipping.
# Folder 20221213 does not exist. Skipping.
# Folder 20230126 does not exist. Skipping.
# Error parsing data/news\20230211\Anisakis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Ascaris.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Avian flu.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Botulism.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Chagas disease.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Chikungunya.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Coccidioidomycosis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Communicable disease.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Congo-Crimean HF.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Coronavirus Infection.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Coxsackie Infection.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\CreutzfeldtJakobDisease.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Diphtheria.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Ebola Hemorrhagic Fever.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Enteritis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Enterobiasis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Escherichia coli Infection.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Fasciola.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Filovirus.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Food poisoning.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Food-borne.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Giardiasis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Gonococcal.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Haemophilus influenzae Infection.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Healthcare Associated Infections.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Hepatitis A.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Hepatitis B.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Hepatitis C.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Lassa Fever.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Legionellosis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Leishmaniasis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Leprosy.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Lyme disease.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Measles.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Mumps.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Norovirus.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Nosocomial.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Onchocerciasis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Poliomyelitis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Q Fever.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Rabies.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Respiratory Syncytial Virus Infection.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Salmonellosis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\SARS.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Saxitoxin Poisoning.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Sleeping Sickness.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\STD.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Strongyloidiasis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Swine Flu.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Tetanus.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Toxoplasma.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Trichuris.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Tuberculosis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Tularemia.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Typhoid Fever.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Viral hepatitis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Visceral Leishmaniasis.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\West Nile Disease.xml: no element found: line 1, column 0
# Error parsing data/news\20230211\Yaws.xml: no element found: line 1, column 0
# Folder 20230213 does not exist. Skipping.
# Folder 20230506 does not exist. Skipping.
# Folder 20230507 does not exist. Skipping.
# Folder 20230508 does not exist. Skipping.
# Folder 20230706 does not exist. Skipping.
# Folder 20230709 does not exist. Skipping.
# Folder 20230829 does not exist. Skipping.
# Folder 20230830 does not exist. Skipping.
# Folder 20230901 does not exist. Skipping.
# Folder 20230902 does not exist. Skipping.
# Folder 20230903 does not exist. Skipping.
# Folder 20230904 does not exist. Skipping.
